# %%
# x (batch_size, seq_len, d_embedding)
# -> x @ W_q -> q
# -> x @ W_k -> k
# -> x @ W_v -> v

# atten = q @ k.T * scale_factor * normalization dim: (seq_len, seq_len)
# return proj ( atten @ v )
