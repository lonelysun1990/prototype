# %%
from torch.utils.data import Dataset, DataLoader
import torch

# %%
import numpy as np

# %%
class MyTensorDataset(Dataset):
    def __init__(self, X, y):
        # X, y are both numpy arrays, y is binary
        self.X = torch.tensor(X, dtype = torch.float32)
        self.y = torch.tensor(y, dtype = torch.long)

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        return self.X[idx, ...], self.y[idx, ...]

# %%
x = np.random.rand(500, 10, 24)
y = np.random.randint(0, 2, (500))

dataset = MyTensorDataset(x, y)

# %%
x_sample, y_sample = dataset[0]

# %%
x_sample.shape
# Out:
# torch.Size([10, 24])

# %%
y_sample.item()
# Out:
# 1

# %%
dataloader = DataLoader(dataset, batch_size = 32, shuffle = True)

# %%
n_epoch = 100

for epoch in range(n_epoch):
    running_loss = 0
    for input, target in dataloader:
        optimizer.zero_grad()
        loss = loss_fn(model(input), target)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

# %%
import pandas as pd

# %%
import pandas as pd

df = pd.DataFrame({
    "user_id": [1,2,3,4],
    "age": [23,45,31,19],
    "country": ["US","US","UK","US"]
})

# %%
df.head(2)
# Out:
#    user_id  age country
# 0        1   23      US
# 1        2   45      US

# %%
# Return users older than 25 from the US.

# %%
df[(df['age']>25) & (df['country']== 'US')]
# Out:
#    user_id  age country
# 1        2   45      US

# %%
df = pd.DataFrame({
    "user_id":[1,2,1,3,2],
    "purchase":[100,200,50,80,120],
    "other":[100,200,300,400,500]
})

# %%
df.head()
# Out:
#    user_id  purchase  other
# 0        1       100    100
# 1        2       200    200
# 2        1        50    300
# 3        3        80    400
# 4        2       120    500

# %%
# Compute total purchase per user.

# %%
df.groupby("user_id")["purchase"].sum()
# Out:
# user_id
# 1    150
# 2    320
# 3     80
# Name: purchase, dtype: int64

# %%
df_per_user = df.groupby("user_id").sum()

# %%
df_per_user
# Out:
#          purchase  other
# user_id
# 1             150    400
# 2             320    700
# 3              80    400

# %%
# Sort users by other amount descending.

# %%
df_per_user.sort_values(["other", "purchase"], ascending=False)
# Out:
#          purchase  other
# user_id
# 2             320    700
# 1             150    400
# 3              80    400

# %%
df = pd.DataFrame({
    "user_id":[1,1,1,2,2,3],
    "product":["A","B","A","A","C","B"]
})

# %%
# Find number of unique products each user bought.

# %%
df.groupby("user_id")["product"].nunique()
# Out:
# user_id
# 1    2
# 2    2
# 3    1
# Name: product, dtype: int64

# %%
df.groupby("user_id").nunique()
# Out:
#          product
# user_id
# 1              2
# 2              2
# 3              1

# %%
df = pd.DataFrame({
    "user":[1,2,3,4],
    "age":[25,None,30,None]
})

# %%
df.head()
# Out:
#    user   age
# 0     1  25.0
# 1     2   NaN
# 2     3  30.0
# 3     4   NaN

# %%
df['age'].fillna(df['age'].median(), inplace=True)
# Out:
# /var/folders/vd/69kmbq6s0s331vf09zfxgmh40000gn/T/ipykernel_65700/1654433547.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(), inplace=True)

# %%
df.head()
# Out:
#    user   age
# 0     1  25.0
# 1     2  27.5
# 2     3  30.0
# 3     4  27.5

# %%
df = pd.DataFrame({
    "price":[10,20,30],
    "quantity":[1,3,2]
})

# %%
# Create a column total = price * quantity

# %%
df["total"] = df["price"] * df["quantity"]

# %%
users = pd.DataFrame({
    "user_id":[1,2,3],
    "country":["US","UK","US"]
})

# %%
orders = pd.DataFrame({
    "user_id":[1,1,2],
    "amount":[100,50,80]
})

# %%
pd.merge(users, orders, on="user_id", how="left")
# Out:
#    user_id country  amount
# 0        1      US   100.0
# 1        1      US    50.0
# 2        2      UK    80.0
# 3        3      US     NaN
